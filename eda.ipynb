# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pprint

# %% [markdown]
# ## ADL falls dataset
# https://www.sciencedirect.com/science/article/pii/S2352340923008740#abs0001

# %%
# Load the dataset
df2 = pd.read_csv(
    "./combined_ADLfalls_data.csv",
    dtype={"x": "float64", "y": "float64", "z": "float64"}
)

# %%
# First few rows
print (df2.head(), '\n\n')
# Out:
#       timestamp         x         y         z sensor_type  activity_label  \
# 0  1.820000e+11  0.126893 -0.033519  0.067038         acc  Walking slowly
# 1  1.820000e+11 -0.268151 -0.167594  0.122104         acc  Walking slowly
# 2  1.830000e+11 -0.883460 -0.119710 -0.392649         acc  Walking slowly
# 3  1.830000e+11 -0.253785  0.605733 -0.526724         acc  Walking slowly
# 4  1.830000e+11 -0.189142  0.136469  0.165200         acc  Walking slowly
#
#    user_id
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
# Summarising structure
print(df2.info(), '\n\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2568079 entries, 0 to 2568078
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   timestamp       float64
#  1   x               float64
#  2   y               float64
#  3   z               float64
#  4   sensor_type     object
#  5   activity_label  object
#  6   user_id         int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 137.2+ MB
# None

# %%
print(df2.head())
# Out:
#       timestamp         x         y         z sensor_type  activity_label  \
# 0  1.820000e+11  0.126893 -0.033519  0.067038         acc  Walking slowly
# 1  1.820000e+11 -0.268151 -0.167594  0.122104         acc  Walking slowly
# 2  1.830000e+11 -0.883460 -0.119710 -0.392649         acc  Walking slowly
# 3  1.830000e+11 -0.253785  0.605733 -0.526724         acc  Walking slowly
# 4  1.830000e+11 -0.189142  0.136469  0.165200         acc  Walking slowly
#
#    user_id
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# ### Reconstruct timestamp using 20Hz

# %%
# Ensure timestamp is numeric
df2['timestamp'] = pd.to_numeric(df2['timestamp'], errors='coerce')

print(df2['timestamp'].diff())
# Out:
# 0                   NaN
# 1          0.000000e+00
# 2          1.000000e+09
# 3          0.000000e+00
# 4          0.000000e+00
#                ...
# 2568074    0.000000e+00
# 2568075    0.000000e+00
# 2568076    0.000000e+00
# 2568077    0.000000e+00
# 2568078    0.000000e+00
# Name: timestamp, Length: 2568079, dtype: float64

# %%
import pandas as pd

# Sort data properly
df2 = df2.sort_values(['user_id', 'activity_label', 'sensor_type', 'timestamp'])

# Compute time differences in seconds
df2['time_diff_sec'] = df2.groupby(['user_id', 'activity_label', 'sensor_type'])['timestamp'].diff() / 1e9

# Summary stats per sensor type
sampling_summary = (
    df2.groupby('sensor_type')['time_diff_sec']
       .agg(['min', 'max', 'median', 'mean'])
)

print(sampling_summary)
# Out:
#              min           max  median       mean
# sensor_type
# acc          0.0  602923.93582     0.0   1.983798
# acg          0.0  150460.00000     0.0   0.737863
# gyro         0.0  314000.00000     0.0   1.224671
# hrt          0.0  602632.00000     0.0  18.193957
# mgm          0.0  599940.00000     0.0   1.686121

# %% [markdown]
# Timestamp dt is odd, many timestamps have no difference.
# But the data source says data sampled at 20Hz. we can create timestamp then check if movement makes sense.

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2568079 entries, 1687530 to 1278974
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   timestamp       float64
#  1   x               float64
#  2   y               float64
#  3   z               float64
#  4   sensor_type     object
#  5   activity_label  object
#  6   user_id         int64
#  7   time_diff_sec   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 176.3+ MB
# None

# %%
import numpy as np
import pandas as pd

# Define sampling rates (Hz = samples per second)
sampling_rates = {
    'acc': 20,
    'gyro': 20,
    'acg': 20,
    'mgm': 20,
    'hrt': 1   # change name to match if you have HR sensor
}

df2["timestamp_clean"] = 0.0  # initialize

for (uid, act, sensor), g in df2.groupby(["user_id","activity_label","sensor_type"], group_keys=False):
    hz = sampling_rates.get(sensor, 20)
    n = len(g)
    df2.loc[g.index, "timestamp_clean"] = np.arange(n) / hz

# Now recompute time diffs
df2["time_diff_sec"] = (
    df2.groupby(["user_id", "activity_label", "sensor_type"])["timestamp_clean"].diff()
)

# Force to numeric
df2["timestamp_clean"] = pd.to_numeric(df2["timestamp_clean"], errors="coerce")
df2["time_diff_sec"] = pd.to_numeric(df2["time_diff_sec"], errors="coerce")


# Recalculate ROC using clean timestamps
df2[["roc_x", "roc_y", "roc_z"]] = (
    df2.groupby(["user_id", "activity_label", "sensor_type"])[["x", "y", "z"]]
       .diff()
    .div(df2["time_diff_sec"], axis=0)
)

# Drop the first row of each group (where diffs are NaN)
df2 = df2[df2.groupby(["user_id", "activity_label", "sensor_type"]).cumcount() != 0].reset_index(drop=True)

# %%
# Create a new column "vec_sum", initialize with NaN
df2["vec_sum"] = np.nan  

# Compute only for sensor types not equal to 'hrt'
mask = df2["sensor_type"] != "hrt"
df2.loc[mask, "vec_sum"] = np.sqrt(
    df2.loc[mask, "x"]**2 +
    df2.loc[mask, "y"]**2 +
    df2.loc[mask, "z"]**2
)

# %%
print(df2.head())
# Out:
#       timestamp         x         y         z sensor_type  \
# 0  3.660000e+12 -0.011971  0.081403  0.088585         acc
# 1  3.660000e+12 -0.220267  0.040701 -0.090980         acc
# 2  3.660000e+12  0.203507 -0.287304  0.052672         acc
# 3  3.660000e+12  0.023942  0.004788  0.033519         acc
# 4  3.660000e+12  0.100556 -0.110133 -0.033519         acc
#
#                        activity_label  user_id  time_diff_sec  \
# 0  Backward fall from seated position        1           0.05
# 1  Backward fall from seated position        1           0.05
# 2  Backward fall from seated position        1           0.05
# 3  Backward fall from seated position        1           0.05
# 4  Backward fall from seated position        1           0.05
#
#    timestamp_clean     roc_x     roc_y     roc_z   vec_sum
# 0             0.05 -0.143652  0.239420  2.154782  0.120901
# 1             0.10 -4.165911 -0.814029 -3.591303  0.241767
# 2             0.15  8.475474 -6.560113  2.873042  0.355996
# 3             0.20 -3.591302  5.841852 -0.383072  0.041469
# 4             0.25  1.532289 -2.298434 -1.340753  0.152854

# %% [markdown]
# ### Form mean, standard deviation features

# %%
import pandas as pd

# Rename the last unnamed column (assumed to be the sensor type)
# if df2.columns[5].startswith('Unnamed'):
#     df2 = df2.rename(columns={df2.columns[5]: 'sensor_type'})

# Filter rows with expected sensor types only (optional for safety)
valid_sensors = ['gyro', 'acc', 'acg', 'mgm', 'hrt']
df2 = df2[df2['sensor_type'].isin(valid_sensors)]

# Keep only expected sensor types
# df2[['x', 'y', 'z']] = df2[['x', 'y', 'z']].apply(pd.to_numeric, errors='coerce')


# # Ensure t is numeric
# df2['t'] = pd.to_numeric(df2['t'], errors='coerce')

# # Compute time difference within each user/activity/sensor group
# df2['time_diff'] = (
#     df2.groupby(['user_id', 'activity_label', 'sensor_type'])['t'].diff()
# )

# # assuming t is in nanoseconds, so divide by 1e9
# df2['time_diff_sec'] = df2['time_diff'] / 1e9


# # Calculate rate of change within each user/activity/sensor group (dx,dy,dz)
# df2 = df2.sort_values(['user_id', 'activity_label', 'sensor_type', 'time_diff_sec'])

# df2[['roc_x', 'roc_y', 'roc_z']] = (
#     df2.groupby(['user_id', 'activity_label', 'sensor_type'])[['x', 'y', 'z']]
#         .diff()
# )

# # normalize by time difference (dt)
# df2[['roc_x', 'roc_y', 'roc_z']] = df2[['roc_x', 'roc_y', 'roc_z']].div(df2['time_diff_sec'], axis=0)

# # Drop rows where time_diff_sec <= 0 or NaN (first row of each group, or duplicate timestamps)
# df2 = df2[df2['time_diff_sec'] > 0]

# # Aggregate mean and std for x, y, z, and roc_x, roc_y, roc_z
# sensor_features = (
#     df2.groupby(['user_id', 'activity_label', 'sensor_type'])
#        [['x', 'y', 'z', 'roc_x', 'roc_y', 'roc_z']]
#        .agg(['mean', 'std'])
# )

# # Flatten multi-index column names
# sensor_features.columns = ['_'.join(col) for col in sensor_features.columns]

# # Reset index
# sensor_features = sensor_features.reset_index()

# %%
print(df2)
# Out:
#             timestamp          x         y          z sensor_type  \
# 0        3.660000e+12  -0.011971  0.081403   0.088585         acc
# 1        3.660000e+12  -0.220267  0.040701  -0.090980         acc
# 2        3.660000e+12   0.203507 -0.287304   0.052672         acc
# 3        3.660000e+12   0.023942  0.004788   0.033519         acc
# 4        3.660000e+12   0.100556 -0.110133  -0.033519         acc
# ...               ...        ...       ...        ...         ...
# 2563174  6.120000e+14  13.440000 -9.300000  24.300000         mgm
# 2563175  6.120000e+14  13.740000 -8.700000  24.660000         mgm
# 2563176  6.120000e+14  14.219999 -7.740000  25.080000         mgm
# 2563177  6.120000e+14  14.759999 -6.600000  26.039999         mgm
# 2563178  6.120000e+14  15.299999 -6.120000  25.800000         mgm
#
#                              activity_label  user_id  time_diff_sec  \
# 0        Backward fall from seated position        1           0.05
# 1        Backward fall from seated position        1           0.05
# 2        Backward fall from seated position        1           0.05
# 3        Backward fall from seated position        1           0.05
# 4        Backward fall from seated position        1           0.05
# ...                                     ...      ...            ...
# 2563174                      Walking slowly       41           0.05
# 2563175                      Walking slowly       41           0.05
# 2563176                      Walking slowly       41           0.05
# 2563177                      Walking slowly       41           0.05
# 2563178                      Walking slowly       41           0.05
#
#          timestamp_clean      roc_x      roc_y      roc_z    vec_sum
# 0                   0.05  -0.143652   0.239420   2.154782   0.120901
# 1                   0.10  -4.165911  -0.814029  -3.591303   0.241767
# 2                   0.15   8.475474  -6.560113   2.873042   0.355996
# 3                   0.20  -3.591302   5.841852  -0.383072   0.041469
# 4                   0.25   1.532289  -2.298434  -1.340753   0.152854
# ...                  ...        ...        ...        ...        ...
# 2563174            30.70 -14.400000  12.000000  12.000020  29.285041
# 2563175            30.75   6.000000  12.000000   7.200000  29.539689
# 2563176            30.80   9.599980  19.200000   8.400000  29.851673
# 2563177            30.85  10.800000  22.800000  19.199980  30.651250
# 2563178            30.90  10.800000   9.600000  -4.799980  30.613467
#
# [2563159 rows x 13 columns]

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2563159 entries, 0 to 2563178
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   timestamp        float64
#  1   x                float64
#  2   y                float64
#  3   z                float64
#  4   sensor_type      object
#  5   activity_label   object
#  6   user_id          int64
#  7   time_diff_sec    float64
#  8   timestamp_clean  float64
#  9   roc_x            float64
#  10  roc_y            float64
#  11  roc_z            float64
#  12  vec_sum          float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 273.8+ MB
# None

# %%
# print(sensor_features)
# Out:
#       user_id                      activity_label sensor_type      x_mean  \
# 0           1  Backward fall from seated position         acc   -0.110670
# 1           1  Backward fall from seated position         acg    1.789186
# 2           1  Backward fall from seated position        gyro    0.057254
# 3           1  Backward fall from seated position         hrt  106.701754
# 4           1  Backward fall from seated position         mgm    2.562600
# ...       ...                                 ...         ...         ...
# 4895       41                      Walking slowly         acc   -0.075795
# 4896       41                      Walking slowly         acg   -9.570030
# 4897       41                      Walking slowly        gyro    0.024302
# 4898       41                      Walking slowly         hrt  104.421769
# 4899       41                      Walking slowly         mgm   27.847767
#
#           x_std     y_mean      y_std     z_mean     z_std  roc_x_mean  \
# 0      1.601555   0.200556   1.235462  -0.205179  1.090325   -0.003715
# 1      2.376087  -0.346938   1.073198  -8.857586  3.039827    0.081876
# 2      0.971436  -0.049756   0.403807  -0.070944  0.390867   -0.477673
# 3     10.821547        NaN        NaN        NaN       NaN    0.000000
# 4      1.523233 -13.115400  14.997062  19.428000  2.811185   -1.152000
# ...         ...        ...        ...        ...       ...         ...
# 4895   0.687249   0.197207   1.240626  -0.065809  0.897763   -0.006553
# 4896   0.709327  -1.424126   1.122544   1.456926  0.831339   -0.030011
# 4897   0.775814   0.003150   0.355091   0.003768  0.396626    0.010602
# 4898   3.114098        NaN        NaN        NaN       NaN    0.040816
# 4899   2.780254   6.641553   5.238724  40.538155  4.678626   -0.097087
#
#       roc_x_std  roc_y_mean  roc_y_std  roc_z_mean  roc_z_std
# 0     52.014179   -0.010733  27.176523   -0.013622  31.576759
# 1     15.746432   -0.054387  12.024114    0.073156  33.392435
# 2     30.923968   -0.159304  10.076056    0.066836   9.666673
# 3      4.535574         NaN        NaN         NaN        NaN
# 4     17.025260   -3.660000  70.904056    6.612000  46.825476
# ...         ...         ...        ...         ...        ...
# 4895   5.987283   -0.018915   8.848509   -0.033065   5.240228
# 4896   6.441408    0.095023   8.118777   -0.013330   4.919022
# 4897   6.102713   -0.014554   1.756887    0.010374   2.397152
# 4898   0.628954         NaN        NaN         NaN        NaN
# 4899  14.256002   -0.266019  27.696805    1.186408  28.877082
#
# [4900 rows x 15 columns]

# %%
# print(sensor_features.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4900 entries, 0 to 4899
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         4900 non-null   int64
#  1   activity_label  4900 non-null   object
#  2   sensor_type     4900 non-null   object
#  3   x_mean          4900 non-null   float64
#  4   x_std           4887 non-null   float64
#  5   y_mean          3920 non-null   float64
#  6   y_std           3920 non-null   float64
#  7   z_mean          3920 non-null   float64
#  8   z_std           3920 non-null   float64
#  9   roc_x_mean      4900 non-null   float64
#  10  roc_x_std       4887 non-null   float64
#  11  roc_y_mean      3920 non-null   float64
#  12  roc_y_std       3920 non-null   float64
#  13  roc_z_mean      3920 non-null   float64
#  14  roc_z_std       3920 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 574.3+ KB
# None

# %%
# df2['rotation_magnitude'] = np.sqrt(sensor_features_named['rotation_rate_x']**2 + sensor_features_named['rotation_rate_y']**2 + sensor_features_named['rotation_rate_z']**2)
# df2['acceleration_magnitude'] = np.sqrt(sensor_features_named['user_acceleration_x']**2 + sensor_features_named['user_acceleration_y']**2 + sensor_features_named['user_acceleration_z']**2)
# sensor_features_named['rotation_magnitude_mean'] = sensor_features_named['rotation_magnitude'].mean()
# sensor_features_named['acceleration_magnitude_mean'] = sensor_features_named['acceleration_magnitude'].mean()
# sensor_features_named['rotation_magnitude_std'] = sensor_features_named['rotation_magnitude'].std()
# sensor_features_named['acceleration_magnitude_std'] = sensor_features_named['acceleration_magnitude'].std()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sugar\.conda\envs\iti113\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rotation_rate_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df2['rotation_magnitude'] = np.sqrt(sensor_features_named['rotation_rate_x']**2 + sensor_features_named['rotation_rate_y']**2 + sensor_features_named['rotation_rate_z']**2)
#       2 df2['acceleration_magnitude'] = np.sqrt(sensor_features_named['user_acceleration_x']**2 + sensor_features_named['user_acceleration_y']**2 + sensor_features_named['user_acceleration_z']**2)
#       3 # sensor_features_named['rotation_magnitude_mean'] = sensor_features_named['rotation_magnitude'].mean()
#       4 # sensor_features_named['acceleration_magnitude_mean'] = sensor_features_named['acceleration_magnitude'].mean()
#       5 # sensor_features_named['rotation_magnitude_std'] = sensor_features_named['rotation_magnitude'].std()
#       6 # sensor_features_named['acceleration_magnitude_std'] = sensor_features_named['acceleration_magnitude'].std()
#
# File c:\Users\sugar\.conda\envs\iti113\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\Users\sugar\.conda\envs\iti113\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'rotation_rate_x'

# %% [markdown]
# ### Map sensor names to features names in dryad dataset

# %%
import pandas as pd

# Mapping sensor types to your naming style
sensor_name_map = {
    'gyro': 'rotation_rate',
    'acg': 'user_acceleration',
    'acc': 'acceleration',
    'mgm': 'magnetometer',
    'hrt': 'heart_rate'
}

rows = []

# Group by user, activity, sensor
for (user_id, activity_label, sensor_type), group in df2.groupby(['user_id', 'activity_label', 'sensor_type']):
    sensor = sensor_name_map.get(sensor_type, sensor_type)

    row = {
        'user_id': user_id,
        'activity_label': activity_label
    }

    # Mean and std of x/y/z
    for axis in ['x', 'y', 'z', 'roc_x', 'roc_y', 'roc_z', 'vec_sum']:
        row[f'{sensor}_{axis}_mean'] = group[axis].astype(float).mean()
        row[f'{sensor}_{axis}_std'] = group[axis].astype(float).std()
        # row[f'{sensor}_{axis}'] = group[axis].astype(float).iloc[-1]  # last value # not keeping the original time-series data

    rows.append(row)

# Convert to flat dataframe
sensor_features_named = pd.DataFrame(rows)

# Merge all sensors for same user_id/activity_label
sensor_features_named = (
    sensor_features_named
    .groupby(['user_id', 'activity_label'], as_index=False)
    .first()
)

# %%
print(sensor_features_named.head())
# Out:
#    user_id                      activity_label  acceleration_x_mean  \
# 0        1  Backward fall from seated position            -0.110670
# 1        1              Climbing down normally            -3.362136
# 2        1                Climbing down slowly            -0.287586
# 3        1                Climbing up normally            -0.695586
# 4        1                  Climbing up slowly            -0.263609
#
#    acceleration_x_std  acceleration_y_mean  acceleration_y_std  \
# 0            1.601555             0.200556            1.235462
# 1            5.816553            -0.687240            4.910136
# 2            1.393648            -0.159989            1.583802
# 3            3.534504            -0.084783            2.985748
# 4            1.574136            -0.090240            1.991222
#
#    acceleration_z_mean  acceleration_z_std  acceleration_roc_x_mean  \
# 0            -0.205179            1.090325                -0.003715
# 1            -2.194130            4.528972                -1.243944
# 2            -0.065277            1.378971                -2.573063
# 3            -0.859378            1.759310                -0.985848
# 4            -0.123251            1.410435                -0.057461
#
#    acceleration_roc_x_std  ...  magnetometer_z_mean  magnetometer_z_std  \
# 0               52.014179  ...            19.428000            2.811185
# 1              178.948896  ...           -11.803928           19.070788
# 2               31.358159  ...            -8.594117           16.099127
# 3              107.118511  ...            22.334118           11.993258
# 4               37.315632  ...           -19.219259           24.014963
#
#    magnetometer_roc_x_mean  magnetometer_roc_x_std  magnetometer_roc_y_mean  \
# 0                -1.152000               17.025260                -3.660000
# 1                14.850000              117.467136                -4.585714
# 2                -0.141176              128.645903               -13.694117
# 3               -59.152941              153.505498                17.929413
# 4                 1.081481              104.662313                -4.600000
#
#    magnetometer_roc_y_std  magnetometer_roc_z_mean  magnetometer_roc_z_std  \
# 0               70.904056                 6.612000               46.825476
# 1              167.294431                 8.078571              149.377848
# 2              241.558774                 3.917647              176.837752
# 3              114.927396                 3.600000              129.928057
# 4              100.408755                 1.311111              148.208307
#
#    magnetometer_vec_sum_mean  magnetometer_vec_sum_std
# 0                  27.969177                  2.569525
# 1                  32.559995                 12.535414
# 2                  45.635702                  7.329222
# 3                  41.593905                  7.928454
# 4                  47.495857                 12.684441
#
# [5 rows x 72 columns]

# %%
# mean, std of all the time-based data

print(sensor_features_named.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 72 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   user_id                         980 non-null    int64
#  1   activity_label                  980 non-null    object
#  2   acceleration_x_mean             980 non-null    float64
#  3   acceleration_x_std              980 non-null    float64
#  4   acceleration_y_mean             980 non-null    float64
#  5   acceleration_y_std              980 non-null    float64
#  6   acceleration_z_mean             980 non-null    float64
#  7   acceleration_z_std              980 non-null    float64
#  8   acceleration_roc_x_mean         980 non-null    float64
#  9   acceleration_roc_x_std          980 non-null    float64
#  10  acceleration_roc_y_mean         980 non-null    float64
#  11  acceleration_roc_y_std          980 non-null    float64
#  12  acceleration_roc_z_mean         980 non-null    float64
#  13  acceleration_roc_z_std          980 non-null    float64
#  14  acceleration_vec_sum_mean       980 non-null    float64
#  15  acceleration_vec_sum_std        980 non-null    float64
#  16  user_acceleration_x_mean        980 non-null    float64
#  17  user_acceleration_x_std         980 non-null    float64
#  18  user_acceleration_y_mean        980 non-null    float64
#  19  user_acceleration_y_std         980 non-null    float64
#  20  user_acceleration_z_mean        980 non-null    float64
#  21  user_acceleration_z_std         980 non-null    float64
#  22  user_acceleration_roc_x_mean    980 non-null    float64
#  23  user_acceleration_roc_x_std     980 non-null    float64
#  24  user_acceleration_roc_y_mean    980 non-null    float64
#  25  user_acceleration_roc_y_std     980 non-null    float64
#  26  user_acceleration_roc_z_mean    980 non-null    float64
#  27  user_acceleration_roc_z_std     980 non-null    float64
#  28  user_acceleration_vec_sum_mean  980 non-null    float64
#  29  user_acceleration_vec_sum_std   980 non-null    float64
#  30  rotation_rate_x_mean            980 non-null    float64
#  31  rotation_rate_x_std             980 non-null    float64
#  32  rotation_rate_y_mean            980 non-null    float64
#  33  rotation_rate_y_std             980 non-null    float64
#  34  rotation_rate_z_mean            980 non-null    float64
#  35  rotation_rate_z_std             980 non-null    float64
#  36  rotation_rate_roc_x_mean        980 non-null    float64
#  37  rotation_rate_roc_x_std         980 non-null    float64
#  38  rotation_rate_roc_y_mean        980 non-null    float64
#  39  rotation_rate_roc_y_std         980 non-null    float64
#  40  rotation_rate_roc_z_mean        980 non-null    float64
#  41  rotation_rate_roc_z_std         980 non-null    float64
#  42  rotation_rate_vec_sum_mean      980 non-null    float64
#  43  rotation_rate_vec_sum_std       980 non-null    float64
#  44  heart_rate_x_mean               980 non-null    float64
#  45  heart_rate_x_std                967 non-null    float64
#  46  heart_rate_y_mean               0 non-null      float64
#  47  heart_rate_y_std                0 non-null      float64
#  48  heart_rate_z_mean               0 non-null      float64
#  49  heart_rate_z_std                0 non-null      float64
#  50  heart_rate_roc_x_mean           980 non-null    float64
#  51  heart_rate_roc_x_std            967 non-null    float64
#  52  heart_rate_roc_y_mean           0 non-null      float64
#  53  heart_rate_roc_y_std            0 non-null      float64
#  54  heart_rate_roc_z_mean           0 non-null      float64
#  55  heart_rate_roc_z_std            0 non-null      float64
#  56  heart_rate_vec_sum_mean         0 non-null      float64
#  57  heart_rate_vec_sum_std          0 non-null      float64
#  58  magnetometer_x_mean             980 non-null    float64
#  59  magnetometer_x_std              980 non-null    float64
#  60  magnetometer_y_mean             980 non-null    float64
#  61  magnetometer_y_std              980 non-null    float64
#  62  magnetometer_z_mean             980 non-null    float64
#  63  magnetometer_z_std              980 non-null    float64
#  64  magnetometer_roc_x_mean         980 non-null    float64
#  65  magnetometer_roc_x_std          980 non-null    float64
#  66  magnetometer_roc_y_mean         980 non-null    float64
#  67  magnetometer_roc_y_std          980 non-null    float64
#  68  magnetometer_roc_z_mean         980 non-null    float64
#  69  magnetometer_roc_z_std          980 non-null    float64
#  70  magnetometer_vec_sum_mean       980 non-null    float64
#  71  magnetometer_vec_sum_std        980 non-null    float64
# dtypes: float64(70), int64(1), object(1)
# memory usage: 551.4+ KB
# None

# %%
# original time-based data

print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2563159 entries, 0 to 2563178
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   timestamp        float64
#  1   x                float64
#  2   y                float64
#  3   z                float64
#  4   sensor_type      object
#  5   activity_label   object
#  6   user_id          int64
#  7   time_diff_sec    float64
#  8   timestamp_clean  float64
#  9   roc_x            float64
#  10  roc_y            float64
#  11  roc_z            float64
#  12  vec_sum          float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 273.8+ MB
# None

# %% [markdown]
# ### Fill group_label with volunteer details

# %%
details = pd.read_csv("./volunteer_details.csv")
print(details.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Subject Id         41 non-null     int64
#  1   Gender             41 non-null     object
#  2   Height (cm)        41 non-null     float64
#  3   Weight (KG)        41 non-null     float64
#  4   Age                41 non-null     int64
#  5   Heart Rate (base)  41 non-null     int64
#  6   Health condition   41 non-null     object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 2.4+ KB
# None

# %%
# Convert both ID columns to int type before merging
sensor_features_named['user_id'] = sensor_features_named['user_id'].astype(int)


# Map Health condition to health_status
# details['health_status'] = details['Health condition'].apply(
#     lambda x: 'Healthy' if x == 'No existing Health Issues' else 'Unhealthy'
# )

details['health_status'] = details['Health condition'].apply(
    lambda x: 'Unhealthy' if any(cond in str(x).lower() for cond in ['obese', 'overweight', 'arthritis']) else 'Healthy'
)

# Create age_group based on threshold
details['age_group'] = np.where(details['Age'] <= 35, 'young', 'older')


# Merge the group_label into df based on user_id
sensor_features_named = sensor_features_named.merge(details[['Subject Id', 'health_status', 'age_group']],
              left_on='user_id', right_on='Subject Id', how='left')

# Drop the temporary column
sensor_features_named = sensor_features_named.drop(columns=['Subject Id'])  # Drop Subject Id after merge
print(sensor_features_named.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 74 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   user_id                         980 non-null    int64
#  1   activity_label                  980 non-null    object
#  2   acceleration_x_mean             980 non-null    float64
#  3   acceleration_x_std              980 non-null    float64
#  4   acceleration_y_mean             980 non-null    float64
#  5   acceleration_y_std              980 non-null    float64
#  6   acceleration_z_mean             980 non-null    float64
#  7   acceleration_z_std              980 non-null    float64
#  8   acceleration_roc_x_mean         980 non-null    float64
#  9   acceleration_roc_x_std          980 non-null    float64
#  10  acceleration_roc_y_mean         980 non-null    float64
#  11  acceleration_roc_y_std          980 non-null    float64
#  12  acceleration_roc_z_mean         980 non-null    float64
#  13  acceleration_roc_z_std          980 non-null    float64
#  14  acceleration_vec_sum_mean       980 non-null    float64
#  15  acceleration_vec_sum_std        980 non-null    float64
#  16  user_acceleration_x_mean        980 non-null    float64
#  17  user_acceleration_x_std         980 non-null    float64
#  18  user_acceleration_y_mean        980 non-null    float64
#  19  user_acceleration_y_std         980 non-null    float64
#  20  user_acceleration_z_mean        980 non-null    float64
#  21  user_acceleration_z_std         980 non-null    float64
#  22  user_acceleration_roc_x_mean    980 non-null    float64
#  23  user_acceleration_roc_x_std     980 non-null    float64
#  24  user_acceleration_roc_y_mean    980 non-null    float64
#  25  user_acceleration_roc_y_std     980 non-null    float64
#  26  user_acceleration_roc_z_mean    980 non-null    float64
#  27  user_acceleration_roc_z_std     980 non-null    float64
#  28  user_acceleration_vec_sum_mean  980 non-null    float64
#  29  user_acceleration_vec_sum_std   980 non-null    float64
#  30  rotation_rate_x_mean            980 non-null    float64
#  31  rotation_rate_x_std             980 non-null    float64
#  32  rotation_rate_y_mean            980 non-null    float64
#  33  rotation_rate_y_std             980 non-null    float64
#  34  rotation_rate_z_mean            980 non-null    float64
#  35  rotation_rate_z_std             980 non-null    float64
#  36  rotation_rate_roc_x_mean        980 non-null    float64
#  37  rotation_rate_roc_x_std         980 non-null    float64
#  38  rotation_rate_roc_y_mean        980 non-null    float64
#  39  rotation_rate_roc_y_std         980 non-null    float64
#  40  rotation_rate_roc_z_mean        980 non-null    float64
#  41  rotation_rate_roc_z_std         980 non-null    float64
#  42  rotation_rate_vec_sum_mean      980 non-null    float64
#  43  rotation_rate_vec_sum_std       980 non-null    float64
#  44  heart_rate_x_mean               980 non-null    float64
#  45  heart_rate_x_std                967 non-null    float64
#  46  heart_rate_y_mean               0 non-null      float64
#  47  heart_rate_y_std                0 non-null      float64
#  48  heart_rate_z_mean               0 non-null      float64
#  49  heart_rate_z_std                0 non-null      float64
#  50  heart_rate_roc_x_mean           980 non-null    float64
#  51  heart_rate_roc_x_std            967 non-null    float64
#  52  heart_rate_roc_y_mean           0 non-null      float64
#  53  heart_rate_roc_y_std            0 non-null      float64
#  54  heart_rate_roc_z_mean           0 non-null      float64
#  55  heart_rate_roc_z_std            0 non-null      float64
#  56  heart_rate_vec_sum_mean         0 non-null      float64
#  57  heart_rate_vec_sum_std          0 non-null      float64
#  58  magnetometer_x_mean             980 non-null    float64
#  59  magnetometer_x_std              980 non-null    float64
#  60  magnetometer_y_mean             980 non-null    float64
#  61  magnetometer_y_std              980 non-null    float64
#  62  magnetometer_z_mean             980 non-null    float64
#  63  magnetometer_z_std              980 non-null    float64
#  64  magnetometer_roc_x_mean         980 non-null    float64
#  65  magnetometer_roc_x_std          980 non-null    float64
#  66  magnetometer_roc_y_mean         980 non-null    float64
#  67  magnetometer_roc_y_std          980 non-null    float64
#  68  magnetometer_roc_z_mean         980 non-null    float64
#  69  magnetometer_roc_z_std          980 non-null    float64
#  70  magnetometer_vec_sum_mean       980 non-null    float64
#  71  magnetometer_vec_sum_std        980 non-null    float64
#  72  health_status                   980 non-null    object
#  73  age_group                       980 non-null    object
# dtypes: float64(70), int64(1), object(3)
# memory usage: 566.7+ KB
# None

# %%
# Drop heart rate y and z

drop_cols = ['heart_rate_y','heart_rate_z','heart_rate_roc_y','heart_rate_roc_z','heart_rate_vec_sum']
columns_to_drop = [col for col in sensor_features_named.columns if any(k in col.lower() for k in drop_cols)]

sensor_features_named = sensor_features_named.drop(columns=columns_to_drop)

print(sensor_features_named.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   user_id                         980 non-null    int64
#  1   activity_label                  980 non-null    object
#  2   acceleration_x_mean             980 non-null    float64
#  3   acceleration_x_std              980 non-null    float64
#  4   acceleration_y_mean             980 non-null    float64
#  5   acceleration_y_std              980 non-null    float64
#  6   acceleration_z_mean             980 non-null    float64
#  7   acceleration_z_std              980 non-null    float64
#  8   acceleration_roc_x_mean         980 non-null    float64
#  9   acceleration_roc_x_std          980 non-null    float64
#  10  acceleration_roc_y_mean         980 non-null    float64
#  11  acceleration_roc_y_std          980 non-null    float64
#  12  acceleration_roc_z_mean         980 non-null    float64
#  13  acceleration_roc_z_std          980 non-null    float64
#  14  acceleration_vec_sum_mean       980 non-null    float64
#  15  acceleration_vec_sum_std        980 non-null    float64
#  16  user_acceleration_x_mean        980 non-null    float64
#  17  user_acceleration_x_std         980 non-null    float64
#  18  user_acceleration_y_mean        980 non-null    float64
#  19  user_acceleration_y_std         980 non-null    float64
#  20  user_acceleration_z_mean        980 non-null    float64
#  21  user_acceleration_z_std         980 non-null    float64
#  22  user_acceleration_roc_x_mean    980 non-null    float64
#  23  user_acceleration_roc_x_std     980 non-null    float64
#  24  user_acceleration_roc_y_mean    980 non-null    float64
#  25  user_acceleration_roc_y_std     980 non-null    float64
#  26  user_acceleration_roc_z_mean    980 non-null    float64
#  27  user_acceleration_roc_z_std     980 non-null    float64
#  28  user_acceleration_vec_sum_mean  980 non-null    float64
#  29  user_acceleration_vec_sum_std   980 non-null    float64
#  30  rotation_rate_x_mean            980 non-null    float64
#  31  rotation_rate_x_std             980 non-null    float64
#  32  rotation_rate_y_mean            980 non-null    float64
#  33  rotation_rate_y_std             980 non-null    float64
#  34  rotation_rate_z_mean            980 non-null    float64
#  35  rotation_rate_z_std             980 non-null    float64
#  36  rotation_rate_roc_x_mean        980 non-null    float64
#  37  rotation_rate_roc_x_std         980 non-null    float64
#  38  rotation_rate_roc_y_mean        980 non-null    float64
#  39  rotation_rate_roc_y_std         980 non-null    float64
#  40  rotation_rate_roc_z_mean        980 non-null    float64
#  41  rotation_rate_roc_z_std         980 non-null    float64
#  42  rotation_rate_vec_sum_mean      980 non-null    float64
#  43  rotation_rate_vec_sum_std       980 non-null    float64
#  44  heart_rate_x_mean               980 non-null    float64
#  45  heart_rate_x_std                967 non-null    float64
#  46  heart_rate_roc_x_mean           980 non-null    float64
#  47  heart_rate_roc_x_std            967 non-null    float64
#  48  magnetometer_x_mean             980 non-null    float64
#  49  magnetometer_x_std              980 non-null    float64
#  50  magnetometer_y_mean             980 non-null    float64
#  51  magnetometer_y_std              980 non-null    float64
#  52  magnetometer_z_mean             980 non-null    float64
#  53  magnetometer_z_std              980 non-null    float64
#  54  magnetometer_roc_x_mean         980 non-null    float64
#  55  magnetometer_roc_x_std          980 non-null    float64
#  56  magnetometer_roc_y_mean         980 non-null    float64
#  57  magnetometer_roc_y_std          980 non-null    float64
#  58  magnetometer_roc_z_mean         980 non-null    float64
#  59  magnetometer_roc_z_std          980 non-null    float64
#  60  magnetometer_vec_sum_mean       980 non-null    float64
#  61  magnetometer_vec_sum_std        980 non-null    float64
#  62  health_status                   980 non-null    object
#  63  age_group                       980 non-null    object
# dtypes: float64(60), int64(1), object(3)
# memory usage: 490.1+ KB
# None

# %%
print(sensor_features_named['health_status'].unique())
print(sensor_features_named['age_group'].unique())
# Out:
# ['Healthy' 'Unhealthy']
# ['young' 'older']

# %% [markdown]
# ### Missing values

# %%
# Detecting missing values
missing_list = list(sensor_features_named.columns[sensor_features_named.isna().any()])       

# Percentage of missing values
row_count = sensor_features_named.shape[0] 
# Create list of dicts (one per column)
data = []
for col in missing_list:
    count = sensor_features_named[col].isnull().sum()
    percent = (count / row_count) * 100
    data.append({
        'Columns with missing values': col,
        'Missing count': count,
        'Missing %': percent,
        'DataType' : sensor_features_named[col].dtype
    })

# Create DataFrame from list of dicts
missing_df = pd.DataFrame(data)
print(missing_df)
# Out:
#   Columns with missing values  Missing count  Missing % DataType
# 0            heart_rate_x_std             13   1.326531  float64
# 1        heart_rate_roc_x_std             13   1.326531  float64

# %%
# Checking if missing values have a common pattern (13)

null_val = sensor_features_named[sensor_features_named['heart_rate_x_std'].isnull()]
print(null_val.shape)
for column in null_val.columns:
    print(null_val[column].value_counts(),"\n")
# Out:
# (13, 64)
# user_id
# 1     1
# 3     1
# 6     1
# 7     1
# 11    1
# 21    1
# 25    1
# 26    1
# 28    1
# 30    1
# 35    1
# 37    1
# 39    1
# Name: count, dtype: int64
#
# activity_label
# Slowly sitting on chair                   2
# Forward fall landing on knee              2
# Climbing up normally                      2
# Lying on back and getting up slowly       1
# Nearly sitting on chair and getting up    1
# Grabbing while falling                    1
# Climbing down normally                    1
# Rapidly sitting on chair                  1
# Lying on bed                              1
# Walking slowly                            1
# Name: count, dtype: int64
#
# acceleration_x_mean
# -0.409282    1
#  0.034173    1
#  0.006174    1
#  0.009353    1
# -1.973457    1
#  0.060649    1
# -0.010947    1
#  0.074109    1
#  0.033691    1
#  0.018031    1
#  0.055932    1
# -0.084038    1
#  0.020249    1
# Name: count, dtype: int64
#
# acceleration_x_std
# 0.868738    1
# 0.618508    1
# 0.729795    1
# 3.993570    1
# 7.597158    1
# 0.280410    1
# 2.893882    1
# 1.267732    1
# 0.477888    1
# 0.047933    1
# 0.172681    1
# 1.864353    1
# 0.201440    1
# Name: count, dtype: int64
#
# acceleration_y_mean
# -0.406006    1
# -0.017896    1
# -0.005614    1
# -0.058456    1
# -0.469417    1
#  0.105254    1
# -0.614813    1
# -0.112795    1
# -0.040608    1
# -0.002334    1
#  0.039080    1
# -0.024251    1
# -0.045224    1
# Name: count, dtype: int64
#
# acceleration_y_std
# 1.553311     1
# 0.728701     1
# 0.780763     1
# 1.746499     1
# 11.007067    1
# 0.489044     1
# 2.264134     1
# 1.153549     1
# 0.717440     1
# 0.120961     1
# 0.225593     1
# 1.185931     1
# 0.176523     1
# Name: count, dtype: int64
#
# acceleration_z_mean
#  0.178431    1
#  0.027680    1
#  0.158476    1
# -0.148862    1
# -0.011562    1
# -0.114935    1
#  0.419407    1
#  0.037517    1
#  0.073313    1
#  0.098477    1
# -0.029039    1
#  0.011662    1
#  0.020703    1
# Name: count, dtype: int64
#
# acceleration_z_std
# 0.912293    1
# 0.641478    1
# 0.611935    1
# 3.250763    1
# 8.051485    1
# 0.406048    1
# 1.932820    1
# 1.293032    1
# 0.559727    1
# 0.081147    1
# 0.209442    1
# 1.222015    1
# 0.216292    1
# Name: count, dtype: int64
#
# acceleration_roc_x_mean
# -0.390633    1
# -0.042028    1
# -0.091732    1
#  0.009864    1
# -0.434022    1
#  0.046323    1
#  0.491790    1
# -0.048998    1
#  0.004695    1
#  1.667562    1
#  0.077232    1
# -0.158544    1
#  0.438781    1
# Name: count, dtype: int64
#
# acceleration_roc_x_std
# 15.055747    1
# 14.296323    1
# 17.152091    1
# 43.439397    1
# 99.498735    1
# 4.084182     1
# 23.802499    1
# 7.754653     1
# 7.740812     1
# 21.238952    1
# 2.376327     1
# 14.458130    1
# 6.249850     1
# Name: count, dtype: int64
#
# acceleration_roc_y_mean
#  0.645174    1
#  0.048918    1
# -0.020548    1
#  0.046808    1
#  0.144674    1
# -0.046323    1
# -0.158409    1
# -0.003786    1
#  0.012519    1
#  0.582988    1
# -0.050664    1
#  0.067358    1
#  0.632194    1
# Name: count, dtype: int64
#
# acceleration_roc_y_std
# 35.179196     1
# 17.819329     1
# 18.414876     1
# 17.078961     1
# 207.073690    1
# 6.821820      1
# 14.955474     1
# 8.789671      1
# 13.098643     1
# 7.051191      1
# 2.779606      1
# 6.684587      1
# 9.031301      1
# Name: count, dtype: int64
#
# acceleration_roc_z_mean
# -0.216738    1
# -0.066831    1
#  0.036876    1
# -0.209650    1
# -0.045986    1
#  0.038255    1
# -0.166841    1
#  0.012027    1
# -0.040686    1
# -0.199617    1
#  0.081557    1
# -0.133342    1
#  0.052266    1
# Name: count, dtype: int64
#
# acceleration_roc_z_std
# 25.427992     1
# 9.751325      1
# 8.971364      1
# 20.651382     1
# 132.911815    1
# 6.026649      1
# 16.796650     1
# 9.283923      1
# 6.773911      1
# 2.364829      1
# 2.426650      1
# 6.905089      1
# 1.240595      1
# Name: count, dtype: int64
#
# acceleration_vec_sum_mean
# 1.539402    1
# 0.941579    1
# 0.789753    1
# 2.890828    1
# 7.461045    1
# 0.399858    1
# 3.099084    1
# 1.797037    1
# 0.523727    1
# 0.144072    1
# 0.254422    1
# 2.251576    1
# 0.313018    1
# Name: count, dtype: int64
#
# acceleration_vec_sum_std
# 1.372141     1
# 0.659035     1
# 0.956989     1
# 4.604756     1
# 13.856006    1
# 0.591632     1
# 2.851151     1
# 1.176874     1
# 0.887980     1
# 0.112774     1
# 0.254873     1
# 1.135525     1
# 0.150992     1
# Name: count, dtype: int64
#
# user_acceleration_x_mean
#  2.836052    1
# -9.076322    1
# -9.126203    1
# -8.386889    1
# -3.480240    1
# -7.849403    1
# -9.231984    1
# -8.872880    1
#  8.527571    1
#  1.402853    1
# -8.777312    1
# -9.395361    1
# -9.231000    1
# Name: count, dtype: int64
#
# user_acceleration_x_std
# 4.674399    1
# 0.693726    1
# 0.630648    1
# 4.131757    1
# 8.596376    1
# 2.818227    1
# 2.969893    1
# 1.305979    1
# 1.924183    1
# 0.168039    1
# 1.908387    1
# 1.923406    1
# 0.235348    1
# Name: count, dtype: int64
#
# user_acceleration_y_mean
# -1.494940    1
#  3.195580    1
# -2.834040    1
# -3.719619    1
# -7.228682    1
# -0.960244    1
# -2.520398    1
# -3.550874    1
# -3.235344    1
# -0.658108    1
# -2.139833    1
# -2.270741    1
# -2.425031    1
# Name: count, dtype: int64
#
# user_acceleration_y_std
# 2.214406     1
# 1.665408     1
# 0.686328     1
# 2.291820     1
# 11.218930    1
# 1.936843     1
# 1.314837     1
# 0.779345     1
# 1.164935     1
# 0.295560     1
# 0.742879     1
# 0.792705     1
# 0.312566     1
# Name: count, dtype: int64
#
# user_acceleration_z_mean
# 7.781634    1
# 0.188996    1
# 0.995960    1
# 2.619230    1
# 3.462506    1
# 3.542052    1
# 3.090319    1
# 1.427144    1
# 2.744875    1
# 9.779585    1
# 2.552372    1
# 1.432987    1
# 2.165058    1
# Name: count, dtype: int64
#
# user_acceleration_z_std
# 1.721718    1
# 0.847068    1
# 1.555100    1
# 2.945765    1
# 8.402838    1
# 2.818634    1
# 1.214703    1
# 1.068543    1
# 1.417344    1
# 0.097642    1
# 1.585319    1
# 0.907398    1
# 0.527731    1
# Name: count, dtype: int64
#
# user_acceleration_roc_x_mean
# -0.241815    1
# -0.001294    1
#  0.036370    1
# -0.025455    1
#  0.322251    1
#  0.812988    1
# -0.869168    1
# -0.010501    1
# -1.159478    1
# -0.083277    1
#  1.035953    1
# -0.186748    1
# -0.037934    1
# Name: count, dtype: int64
#
# user_acceleration_roc_x_std
# 77.983399    1
# 14.420471    1
# 3.685425     1
# 36.557044    1
# 97.876086    1
# 15.156230    1
# 24.223524    1
# 8.179274     1
# 14.970992    1
# 1.670189     1
# 12.767834    1
# 15.564352    1
# 3.241467     1
# Name: count, dtype: int64
#
# user_acceleration_roc_y_mean
# -0.174777    1
# -0.178595    1
#  0.308688    1
#  0.229452    1
# -0.761386    1
#  0.503303    1
# -0.149166    1
#  0.095348    1
# -0.298809    1
#  0.068108    1
# -0.239113    1
#  0.029186    1
# -0.036068    1
# Name: count, dtype: int64
#
# user_acceleration_roc_y_std
# 45.738664     1
# 18.527028     1
# 5.049278      1
# 13.573065     1
# 236.545366    1
# 7.168801      1
# 8.982387      1
# 7.393570      1
# 13.057999     1
# 2.686245      1
# 6.821949      1
# 7.000122      1
# 1.546951      1
# Name: count, dtype: int64
#
# user_acceleration_roc_z_mean
#  0.751779    1
# -0.209978    1
#  0.714240    1
#  0.129768    1
#  0.367309    1
#  0.748448    1
#  0.239130    1
# -0.055445    1
#  0.636174    1
# -0.016358    1
#  0.821702    1
# -0.240560    1
# -0.008706    1
# Name: count, dtype: int64
#
# user_acceleration_roc_z_std
# 37.098992     1
# 9.795781      1
# 7.583559      1
# 18.208748     1
# 134.879978    1
# 9.918715      1
# 11.252925     1
# 7.859959      1
# 13.975866     1
# 1.369508      1
# 12.109478     1
# 7.731029      1
# 2.219208      1
# Name: count, dtype: int64
#
# user_acceleration_vec_sum_mean
# 9.934074     1
# 9.811354     1
# 9.766227     1
# 10.399946    1
# 13.153689    1
# 9.720954     1
# 10.227165    1
# 9.751280     1
# 9.878674     1
# 9.907498     1
# 9.734918     1
# 9.836090     1
# 9.806052     1
# Name: count, dtype: int64
#
# user_acceleration_vec_sum_std
# 0.630842     1
# 0.558598     1
# 0.455475     1
# 3.716782     1
# 13.168294    1
# 0.341679     1
# 2.922423     1
# 1.316501     1
# 0.395718     1
# 0.085275     1
# 0.174149     1
# 1.969527     1
# 0.223770     1
# Name: count, dtype: int64
#
# rotation_rate_x_mean
#  0.347872    1
#  0.092351    1
#  0.327312    1
#  0.393616    1
#  0.020263    1
# -0.060887    1
# -0.037216    1
#  0.038931    1
#  0.046306    1
# -0.004330    1
#  0.011989    1
#  0.024961    1
# -0.029888    1
# Name: count, dtype: int64
#
# rotation_rate_x_std
# 0.993019    1
# 0.367992    1
# 0.582541    1
# 1.074520    1
# 1.736956    1
# 0.638432    1
# 0.924739    1
# 0.790459    1
# 0.218290    1
# 0.050486    1
# 0.164125    1
# 0.867509    1
# 0.233142    1
# Name: count, dtype: int64
#
# rotation_rate_y_mean
#  0.296430    1
#  0.069085    1
#  0.074903    1
#  0.090873    1
#  0.024724    1
# -0.000863    1
# -0.109290    1
# -0.054932    1
# -0.134646    1
#  0.000596    1
#  0.017459    1
# -0.017893    1
#  0.036876    1
# Name: count, dtype: int64
#
# rotation_rate_y_std
# 0.621043    1
# 0.187885    1
# 0.131764    1
# 0.597523    1
# 1.486499    1
# 0.129278    1
# 0.494755    1
# 0.417231    1
# 0.295864    1
# 0.016183    1
# 0.073553    1
# 0.310391    1
# 0.158746    1
# Name: count, dtype: int64
#
# rotation_rate_z_mean
#  0.456927    1
# -0.037874    1
#  0.146486    1
# -0.000697    1
# -0.524282    1
#  0.010830    1
#  0.044186    1
# -0.055927    1
# -0.061566    1
#  0.000848    1
#  0.034957    1
#  0.113253    1
#  0.057078    1
# Name: count, dtype: int64
#
# rotation_rate_z_std
# 0.831377    1
# 0.420728    1
# 0.359060    1
# 0.747836    1
# 2.098018    1
# 0.413927    1
# 0.986952    1
# 0.747106    1
# 0.260520    1
# 0.043207    1
# 0.110158    1
# 0.709776    1
# 0.293358    1
# Name: count, dtype: int64
#
# rotation_rate_roc_x_mean
# -0.109313    1
#  0.017403    1
#  0.028445    1
#  0.025802    1
#  0.009134    1
#  0.039706    1
# -0.060147    1
#  0.011479    1
#  0.041842    1
#  0.052534    1
#  0.043825    1
#  0.135384    1
# -0.012297    1
# Name: count, dtype: int64
#
# rotation_rate_roc_x_std
# 21.255609    1
# 4.268899     1
# 2.669387     1
# 6.446251     1
# 22.092074    1
# 6.642777     1
# 8.386365     1
# 6.126077     1
# 2.633281     1
# 0.815339     1
# 1.413407     1
# 5.695761     1
# 2.525213     1
# Name: count, dtype: int64
#
# rotation_rate_roc_y_mean
# -0.113171    1
#  0.030763    1
#  0.006342    1
# -0.010759    1
# -0.034711    1
# -0.007569    1
#  0.197826    1
# -0.002728    1
# -0.014373    1
# -0.009468    1
# -0.018602    1
#  0.007716    1
#  0.069311    1
# Name: count, dtype: int64
#
# rotation_rate_roc_y_std
# 12.004696    1
# 1.361429     1
# 0.790416     1
# 3.654949     1
# 11.996501    1
# 1.112745     1
# 4.048330     1
# 2.238697     1
# 2.209434     1
# 0.635678     1
# 0.781372     1
# 2.498014     1
# 1.303935     1
# Name: count, dtype: int64
#
# rotation_rate_roc_z_mean
# -0.057871    1
# -0.038322    1
#  0.021357    1
#  0.014041    1
# -0.073152    1
# -0.009960    1
#  0.072051    1
#  0.002387    1
#  0.021081    1
#  0.020159    1
#  0.019863    1
#  0.033788    1
#  0.222786    1
# Name: count, dtype: int64
#
# rotation_rate_roc_z_std
# 13.192660    1
# 3.539264     1
# 1.671625     1
# 3.997114     1
# 13.544461    1
# 3.880016     1
# 8.334921     1
# 4.229609     1
# 2.661810     1
# 1.323920     1
# 1.374091     1
# 4.782141     1
# 3.987422     1
# Name: count, dtype: int64
#
# rotation_rate_vec_sum_mean
# 1.051432    1
# 0.533217    1
# 0.573420    1
# 0.886633    1
# 2.013641    1
# 0.381100    1
# 1.066066    1
# 0.948922    1
# 0.248940    1
# 0.023744    1
# 0.174053    1
# 1.082594    1
# 0.314361    1
# Name: count, dtype: int64
#
# rotation_rate_vec_sum_std
# 1.156250    1
# 0.276030    1
# 0.538782    1
# 1.202341    1
# 2.416136    1
# 0.673394    1
# 0.972394    1
# 0.678315    1
# 0.406079    1
# 0.064267    1
# 0.125188    1
# 0.434613    1
# 0.267746    1
# Name: count, dtype: int64
#
# heart_rate_x_mean
# 77.0     2
# 101.0    1
# 81.0     1
# 78.0     1
# 64.0     1
# 100.0    1
# 91.0     1
# 108.0    1
# 87.0     1
# 126.0    1
# 86.0     1
# 128.0    1
# Name: count, dtype: int64
#
# Series([], Name: count, dtype: int64)
#
# heart_rate_roc_x_mean
# 0.0     12
# 11.0     1
# Name: count, dtype: int64
#
# Series([], Name: count, dtype: int64)
#
# magnetometer_x_mean
# -27.656666     1
# -3.230625      1
#  4.619516      1
# -15.262588     1
# -2.844774      1
#  31.101257     1
#  4.371097      1
# -2.399710      1
# -23.254109     1
#  109.882743    1
#  21.613691     1
# -1.050164      1
#  32.233469     1
# Name: count, dtype: int64
#
# magnetometer_x_std
# 18.783878    1
# 6.430574     1
# 1.538484     1
# 3.758465     1
# 6.180089     1
# 7.953859     1
# 6.957463     1
# 7.509185     1
# 5.038719     1
# 7.347734     1
# 2.854977     1
# 8.080650     1
# 4.048341     1
# Name: count, dtype: int64
#
# magnetometer_y_mean
# -18.103333    1
# -41.781562    1
# -10.617097    1
#  7.082353     1
#  5.199677     1
# -27.260228    1
#  37.483741    1
#  25.080579    1
#  9.452055     1
#  86.889411    1
# -29.862281    1
#  31.079672    1
# -0.974694     1
# Name: count, dtype: int64
#
# magnetometer_y_std
# 4.376145     1
# 4.253875     1
# 4.096302     1
# 7.538386     1
# 6.997338     1
# 7.095015     1
# 4.631317     1
# 17.570565    1
# 6.347270     1
# 5.982991     1
# 2.307366     1
# 15.887132    1
# 3.163726     1
# Name: count, dtype: int64
#
# magnetometer_z_mean
#  7.960000     1
# -18.667500    1
# -20.842500    1
# -25.883529    1
# -24.063871    1
#  4.845600     1
# -2.432516     1
#  6.795362     1
#  27.235479    1
#  28.998039    1
# -19.737181    1
#  31.753442    1
#  28.460816    1
# Name: count, dtype: int64
#
# magnetometer_z_std
# 6.162310     1
# 2.457700     1
# 2.087914     1
# 1.723290     1
# 4.025019     1
# 3.335371     1
# 8.960076     1
# 9.381211     1
# 3.925942     1
# 5.035793     1
# 3.241901     1
# 10.104851    1
# 12.319113    1
# Name: count, dtype: int64
#
# magnetometer_roc_x_mean
#  36.066667    1
# -4.856250     1
#  0.735484     1
#  3.025882     1
#  0.344516     1
#  1.755428     1
# -0.046452     1
# -0.168116     1
# -0.854795     1
#  12.768628    1
#  0.877852     1
#  1.462295     1
# -1.248980     1
# Name: count, dtype: int64
#
# magnetometer_roc_x_std
# 80.404184    1
# 42.693315    1
# 8.451837     1
# 20.040788    1
# 17.707454    1
# 39.572980    1
# 48.944260    1
# 67.914317    1
# 43.483657    1
# 78.325267    1
# 26.880141    1
# 39.161533    1
# 37.304813    1
# Name: count, dtype: int64
#
# magnetometer_roc_y_mean
# -2.266667     1
# -4.162500     1
# -1.785484     1
#  0.461176     1
#  1.525161     1
# -2.413714     1
# -0.921290     1
# -2.376812     1
# -0.041096     1
#  10.784314    1
# -1.014765     1
#  5.586885     1
# -0.897959     1
# Name: count, dtype: int64
#
# magnetometer_roc_y_std
# 41.087338     1
# 33.002426     1
# 6.506686      1
# 17.300476     1
# 20.838266     1
# 48.243174     1
# 51.844931     1
# 156.230954    1
# 75.876920     1
# 69.212212     1
# 22.909294     1
# 130.153315    1
# 18.678628     1
# Name: count, dtype: int64
#
# magnetometer_roc_z_mean
# -3.533333    1
#  0.515625    1
# -1.475806    1
# -1.345882    1
# -2.941935    1
#  1.872000    1
#  4.312258    1
# -1.368116    1
#  0.838356    1
#  8.784314    1
# -5.186577    1
#  5.029508    1
# -2.579592    1
# Name: count, dtype: int64
#
# magnetometer_roc_z_std
# 52.791130     1
# 14.563391     1
# 19.792070     1
# 14.576328     1
# 23.432591     1
# 25.675501     1
# 44.718903     1
# 53.280838     1
# 50.629698     1
# 53.615763     1
# 31.379194     1
# 99.487699     1
# 133.389890    1
# Name: count, dtype: int64
#
# magnetometer_vec_sum_mean
# 35.655308     1
# 46.520006     1
# 24.258803     1
# 31.955606     1
# 26.452322     1
# 42.979276     1
# 39.719530     1
# 32.947877     1
# 38.064339     1
# 143.138015    1
# 42.063972     1
# 48.424169     1
# 44.928576     1
# Name: count, dtype: int64
#
# magnetometer_vec_sum_std
# 16.966376    1
# 2.349471     1
# 1.846048     1
# 2.357460     1
# 4.189768     1
# 3.278173     1
# 1.262301     1
# 6.823788     1
# 1.879012     1
# 9.558824     1
# 1.711584     1
# 6.942984     1
# 2.896818     1
# Name: count, dtype: int64
#
# health_status
# Healthy      10
# Unhealthy     3
# Name: count, dtype: int64
#
# age_group
# young    7
# older    6
# Name: count, dtype: int64

# %% [markdown]
# No common user_id or activity_label

# %%
import plotly.express as px
import plotly.io as pio

# Set the default renderer to open plots in your web browser ('browser') or inline ('notebook')
pio.renderers.default = 'browser' 

# Subset only columns with missing values, sorted in a certain way to view correlations
missing_list_sort = ['heart_rate_x_std', 
                     'heart_rate_roc_x_std']

missing_df = sensor_features_named[missing_list_sort]

# Filter rows with missing values
missing_rows = missing_df[missing_df.isnull().any(axis=1)]

# Create boolean DataFrame of missing values
mask = missing_rows.isnull()

# Convert to long format for Plotly heatmap
mask_long = mask.reset_index().melt(id_vars='index', var_name='Column', value_name='Is Missing')

# Plot interactive heatmap
fig = px.imshow(
    mask.values,
    labels=dict(x="Column", y="Row Index", color="Missing"),
    x=mask.columns,
    y=mask.index,
    color_continuous_scale=["#ffffff", "#636efa"],  # white for present, blue for missing
    aspect="auto"
)

fig.update_layout(title="Interactive Missing Data Heatmap", height=600)
fig.show()

# %% [markdown]
# the missing data in the 2 columns occur in the same rows.

# %% [markdown]
# ### Standardize activities

# %%
# Target categories
# ['Other exercise' 'Hygiene' 'Work' 'Eat' 'Relax' 'Travel' 'Errands' 'Sleep' 'Socialize' 'Walk' 'Hobby' 'Sitting down' 'Climbing stairs' 'Housework' 'Dressing' 'Run' 'Fall']

# Convert to lowercase for easier matching
sensor_features_named['activity_label'] = sensor_features_named['activity_label'].astype(str).str.lower()

# # Convert to lowercase for easier matching
# target_df['activity_label'] = target_df['activity_label'].astype(str).str.lower()

# Define mapping function
def categorize_activity(label):
    if 'eat' in label or 'meal' in label or 'drink' in label:
        return 'Eat'
    elif 'errand' in label or 'shop' in label or 'store' in label or 'grocer' in label:
        return 'Errands'
    elif 'exercise' in label or  'workout' in label or 'cycle' in label or  'jump' in label:
        return 'Other exercise'
    elif 'run' in label or 'jog' in label:
        return 'Run'
    elif 'walk' in label:
        return 'Walk'
    elif 'climb' in label:
        return 'Climbing stairs'
    elif 'sit' in label:
        return 'Sitting down'
    elif 'game' in label or 'gaming' in label or 'play' in label or 'art' in label or 'tv' in label or 'read' in label or 'video' in label:
        return 'Hobby'
    elif 'clean' in label or 'chores' in label or 'housework' in label or 'dishes' in label or 'cook' in label:
        return 'Housework'
    elif 'brush' in label or 'toilet' in label or 'shower' in label or 'hygiene' in label or 'groom' in label or 'bath' in label:
        return 'Hygiene'
    elif 'dress' in label or 'makeup' in label or 'hair' in label:
        return 'Dressing'
    elif 'relax' in label or 'chill' in label or 'rest' in label or 'watch' in label:
        return 'Relax'
    elif 'sleep' in label or 'lying' in label or 'lie' in label: # or 'wake' in label or 'bed' in label or 'woke' in label:
        return 'Sleep'
    elif 'social' in label or 'talk' in label or 'phone' in label or 'message' in label or 'text' in label:
        return 'Socialize'
    elif 'travel' in label or 'bus' in label or 'drive' in label or 'commute' in label: # or 'fly' in label
        return 'Travel'
    elif 'work' in label or 'school' in label or 'lab' in label or 'homework' in label or 'report' in label or 'meeting' in label or 'class' in label or 'research' in label or 'study' in label:
        return 'Work'
    elif 'fall' in label:
        return 'Fall'
    else:
        return None # rows not in the above categories will be dropped

# Apply the categorization
sensor_features_named['activity_label'] = sensor_features_named['activity_label'].apply(categorize_activity)

# Drop rows where category is None (would have been 'Other')
sensor_features_named = sensor_features_named[sensor_features_named['activity_label'].notna()]

# # Apply the categorization
# target_df['activity_category'] = target_df['activity_label'].apply(categorize_activity)

# # Drop rows where category is None (would have been 'Other')
# target_df = target_df[target_df['activity_category'].notna()]

# %%
print(sensor_features_named['activity_label'].unique())
# Out:
# ['Eat' 'Climbing stairs' 'Fall' 'Run' 'Other exercise' 'Sleep'
#  'Sitting down' 'Walk']

# %%
print(sensor_features_named.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 939 entries, 0 to 979
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   user_id                         939 non-null    int64
#  1   activity_label                  939 non-null    object
#  2   acceleration_x_mean             939 non-null    float64
#  3   acceleration_x_std              939 non-null    float64
#  4   acceleration_y_mean             939 non-null    float64
#  5   acceleration_y_std              939 non-null    float64
#  6   acceleration_z_mean             939 non-null    float64
#  7   acceleration_z_std              939 non-null    float64
#  8   acceleration_roc_x_mean         939 non-null    float64
#  9   acceleration_roc_x_std          939 non-null    float64
#  10  acceleration_roc_y_mean         939 non-null    float64
#  11  acceleration_roc_y_std          939 non-null    float64
#  12  acceleration_roc_z_mean         939 non-null    float64
#  13  acceleration_roc_z_std          939 non-null    float64
#  14  acceleration_vec_sum_mean       939 non-null    float64
#  15  acceleration_vec_sum_std        939 non-null    float64
#  16  user_acceleration_x_mean        939 non-null    float64
#  17  user_acceleration_x_std         939 non-null    float64
#  18  user_acceleration_y_mean        939 non-null    float64
#  19  user_acceleration_y_std         939 non-null    float64
#  20  user_acceleration_z_mean        939 non-null    float64
#  21  user_acceleration_z_std         939 non-null    float64
#  22  user_acceleration_roc_x_mean    939 non-null    float64
#  23  user_acceleration_roc_x_std     939 non-null    float64
#  24  user_acceleration_roc_y_mean    939 non-null    float64
#  25  user_acceleration_roc_y_std     939 non-null    float64
#  26  user_acceleration_roc_z_mean    939 non-null    float64
#  27  user_acceleration_roc_z_std     939 non-null    float64
#  28  user_acceleration_vec_sum_mean  939 non-null    float64
#  29  user_acceleration_vec_sum_std   939 non-null    float64
#  30  rotation_rate_x_mean            939 non-null    float64
#  31  rotation_rate_x_std             939 non-null    float64
#  32  rotation_rate_y_mean            939 non-null    float64
#  33  rotation_rate_y_std             939 non-null    float64
#  34  rotation_rate_z_mean            939 non-null    float64
#  35  rotation_rate_z_std             939 non-null    float64
#  36  rotation_rate_roc_x_mean        939 non-null    float64
#  37  rotation_rate_roc_x_std         939 non-null    float64
#  38  rotation_rate_roc_y_mean        939 non-null    float64
#  39  rotation_rate_roc_y_std         939 non-null    float64
#  40  rotation_rate_roc_z_mean        939 non-null    float64
#  41  rotation_rate_roc_z_std         939 non-null    float64
#  42  rotation_rate_vec_sum_mean      939 non-null    float64
#  43  rotation_rate_vec_sum_std       939 non-null    float64
#  44  heart_rate_x_mean               939 non-null    float64
#  45  heart_rate_x_std                926 non-null    float64
#  46  heart_rate_roc_x_mean           939 non-null    float64
#  47  heart_rate_roc_x_std            926 non-null    float64
#  48  magnetometer_x_mean             939 non-null    float64
#  49  magnetometer_x_std              939 non-null    float64
#  50  magnetometer_y_mean             939 non-null    float64
#  51  magnetometer_y_std              939 non-null    float64
#  52  magnetometer_z_mean             939 non-null    float64
#  53  magnetometer_z_std              939 non-null    float64
#  54  magnetometer_roc_x_mean         939 non-null    float64
#  55  magnetometer_roc_x_std          939 non-null    float64
#  56  magnetometer_roc_y_mean         939 non-null    float64
#  57  magnetometer_roc_y_std          939 non-null    float64
#  58  magnetometer_roc_z_mean         939 non-null    float64
#  59  magnetometer_roc_z_std          939 non-null    float64
#  60  magnetometer_vec_sum_mean       939 non-null    float64
#  61  magnetometer_vec_sum_std        939 non-null    float64
#  62  health_status                   939 non-null    object
#  63  age_group                       939 non-null    object
# dtypes: float64(60), int64(1), object(3)
# memory usage: 476.8+ KB
# None

# %% [markdown]
# ### Saving ADL falls dataset

# %%
# Save renamed ADL falls dataset
# sensor_features_named.to_csv("ADLfalls_renamed.csv", index=False)
sensor_features_named.to_csv("ADLfalls_renamed_relabelledHealth_limitedActivities.csv", index=False)

# %% [markdown]
# ## Cleaned ADL falls dataset

# %%
# Load renamed ADL falls dataset
df3 = pd.read_csv("./ADLfalls_renamed.csv")

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 100 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       980 non-null    int64
#  1   activity_label                980 non-null    object
#  2   acceleration_x_mean           980 non-null    float64
#  3   acceleration_x_std            980 non-null    float64
#  4   acceleration_x                980 non-null    float64
#  5   acceleration_y_mean           980 non-null    float64
#  6   acceleration_y_std            980 non-null    float64
#  7   acceleration_y                980 non-null    float64
#  8   acceleration_z_mean           980 non-null    float64
#  9   acceleration_z_std            980 non-null    float64
#  10  acceleration_z                980 non-null    float64
#  11  acceleration_roc_x_mean       980 non-null    float64
#  12  acceleration_roc_x_std        980 non-null    float64
#  13  acceleration_roc_x            980 non-null    float64
#  14  acceleration_roc_y_mean       980 non-null    float64
#  15  acceleration_roc_y_std        980 non-null    float64
#  16  acceleration_roc_y            980 non-null    float64
#  17  acceleration_roc_z_mean       980 non-null    float64
#  18  acceleration_roc_z_std        980 non-null    float64
#  19  acceleration_roc_z            980 non-null    float64
#  20  user_acceleration_x_mean      980 non-null    float64
#  21  user_acceleration_x_std       980 non-null    float64
#  22  user_acceleration_x           980 non-null    float64
#  23  user_acceleration_y_mean      980 non-null    float64
#  24  user_acceleration_y_std       980 non-null    float64
#  25  user_acceleration_y           980 non-null    float64
#  26  user_acceleration_z_mean      980 non-null    float64
#  27  user_acceleration_z_std       980 non-null    float64
#  28  user_acceleration_z           980 non-null    float64
#  29  user_acceleration_roc_x_mean  980 non-null    float64
#  30  user_acceleration_roc_x_std   980 non-null    float64
#  31  user_acceleration_roc_x       980 non-null    float64
#  32  user_acceleration_roc_y_mean  980 non-null    float64
#  33  user_acceleration_roc_y_std   980 non-null    float64
#  34  user_acceleration_roc_y       980 non-null    float64
#  35  user_acceleration_roc_z_mean  980 non-null    float64
#  36  user_acceleration_roc_z_std   980 non-null    float64
#  37  user_acceleration_roc_z       980 non-null    float64
#  38  rotation_rate_x_mean          980 non-null    float64
#  39  rotation_rate_x_std           980 non-null    float64
#  40  rotation_rate_x               980 non-null    float64
#  41  rotation_rate_y_mean          980 non-null    float64
#  42  rotation_rate_y_std           980 non-null    float64
#  43  rotation_rate_y               980 non-null    float64
#  44  rotation_rate_z_mean          980 non-null    float64
#  45  rotation_rate_z_std           980 non-null    float64
#  46  rotation_rate_z               980 non-null    float64
#  47  rotation_rate_roc_x_mean      980 non-null    float64
#  48  rotation_rate_roc_x_std       980 non-null    float64
#  49  rotation_rate_roc_x           980 non-null    float64
#  50  rotation_rate_roc_y_mean      980 non-null    float64
#  51  rotation_rate_roc_y_std       980 non-null    float64
#  52  rotation_rate_roc_y           980 non-null    float64
#  53  rotation_rate_roc_z_mean      980 non-null    float64
#  54  rotation_rate_roc_z_std       980 non-null    float64
#  55  rotation_rate_roc_z           980 non-null    float64
#  56  heart_rate_x_mean             898 non-null    float64
#  57  heart_rate_x_std              869 non-null    float64
#  58  heart_rate_x                  898 non-null    float64
#  59  heart_rate_y_mean             0 non-null      float64
#  60  heart_rate_y_std              0 non-null      float64
#  61  heart_rate_y                  0 non-null      float64
#  62  heart_rate_z_mean             0 non-null      float64
#  63  heart_rate_z_std              0 non-null      float64
#  64  heart_rate_z                  0 non-null      float64
#  65  heart_rate_roc_x_mean         898 non-null    float64
#  66  heart_rate_roc_x_std          869 non-null    float64
#  67  heart_rate_roc_x              898 non-null    float64
#  68  heart_rate_roc_y_mean         0 non-null      float64
#  69  heart_rate_roc_y_std          0 non-null      float64
#  70  heart_rate_roc_y              0 non-null      float64
#  71  heart_rate_roc_z_mean         0 non-null      float64
#  72  heart_rate_roc_z_std          0 non-null      float64
#  73  heart_rate_roc_z              0 non-null      float64
#  74  magnetometer_x_mean           980 non-null    float64
#  75  magnetometer_x_std            980 non-null    float64
#  76  magnetometer_x                980 non-null    float64
#  77  magnetometer_y_mean           980 non-null    float64
#  78  magnetometer_y_std            980 non-null    float64
#  79  magnetometer_y                980 non-null    float64
#  80  magnetometer_z_mean           980 non-null    float64
#  81  magnetometer_z_std            980 non-null    float64
#  82  magnetometer_z                980 non-null    float64
#  83  magnetometer_roc_x_mean       980 non-null    float64
#  84  magnetometer_roc_x_std        980 non-null    float64
#  85  magnetometer_roc_x            980 non-null    float64
#  86  magnetometer_roc_y_mean       980 non-null    float64
#  87  magnetometer_roc_y_std        980 non-null    float64
#  88  magnetometer_roc_y            980 non-null    float64
#  89  magnetometer_roc_z_mean       980 non-null    float64
#  90  magnetometer_roc_z_std        980 non-null    float64
#  91  magnetometer_roc_z            980 non-null    float64
#  92  rotation_magnitude            980 non-null    float64
#  93  acceleration_magnitude        980 non-null    float64
#  94  rotation_magnitude_mean       980 non-null    float64
#  95  acceleration_magnitude_mean   980 non-null    float64
#  96  rotation_magnitude_std        980 non-null    float64
#  97  acceleration_magnitude_std    980 non-null    float64
#  98  health_status                 980 non-null    object
#  99  age_group                     980 non-null    object
# dtypes: float64(96), int64(1), object(3)
# memory usage: 765.8+ KB
# None

# %%
# keywords of columns to keep
eng_cols = ['mean', 'std', 'label', 'id', 'health', 'age']

# Filter columns that contain any of the keywords
columns_to_keep = [col for col in df3.columns if any(k in col.lower() for k in eng_cols)]

# Create a new filtered DataFrame
filtered_df3 = df3[columns_to_keep]
print(filtered_df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       980 non-null    int64
#  1   activity_label                980 non-null    object
#  2   acceleration_x_mean           980 non-null    float64
#  3   acceleration_x_std            980 non-null    float64
#  4   acceleration_y_mean           980 non-null    float64
#  5   acceleration_y_std            980 non-null    float64
#  6   acceleration_z_mean           980 non-null    float64
#  7   acceleration_z_std            980 non-null    float64
#  8   acceleration_roc_x_mean       980 non-null    float64
#  9   acceleration_roc_x_std        980 non-null    float64
#  10  acceleration_roc_y_mean       980 non-null    float64
#  11  acceleration_roc_y_std        980 non-null    float64
#  12  acceleration_roc_z_mean       980 non-null    float64
#  13  acceleration_roc_z_std        980 non-null    float64
#  14  user_acceleration_x_mean      980 non-null    float64
#  15  user_acceleration_x_std       980 non-null    float64
#  16  user_acceleration_y_mean      980 non-null    float64
#  17  user_acceleration_y_std       980 non-null    float64
#  18  user_acceleration_z_mean      980 non-null    float64
#  19  user_acceleration_z_std       980 non-null    float64
#  20  user_acceleration_roc_x_mean  980 non-null    float64
#  21  user_acceleration_roc_x_std   980 non-null    float64
#  22  user_acceleration_roc_y_mean  980 non-null    float64
#  23  user_acceleration_roc_y_std   980 non-null    float64
#  24  user_acceleration_roc_z_mean  980 non-null    float64
#  25  user_acceleration_roc_z_std   980 non-null    float64
#  26  rotation_rate_x_mean          980 non-null    float64
#  27  rotation_rate_x_std           980 non-null    float64
#  28  rotation_rate_y_mean          980 non-null    float64
#  29  rotation_rate_y_std           980 non-null    float64
#  30  rotation_rate_z_mean          980 non-null    float64
#  31  rotation_rate_z_std           980 non-null    float64
#  32  rotation_rate_roc_x_mean      980 non-null    float64
#  33  rotation_rate_roc_x_std       980 non-null    float64
#  34  rotation_rate_roc_y_mean      980 non-null    float64
#  35  rotation_rate_roc_y_std       980 non-null    float64
#  36  rotation_rate_roc_z_mean      980 non-null    float64
#  37  rotation_rate_roc_z_std       980 non-null    float64
#  38  heart_rate_x_mean             898 non-null    float64
#  39  heart_rate_x_std              869 non-null    float64
#  40  heart_rate_y_mean             0 non-null      float64
#  41  heart_rate_y_std              0 non-null      float64
#  42  heart_rate_z_mean             0 non-null      float64
#  43  heart_rate_z_std              0 non-null      float64
#  44  heart_rate_roc_x_mean         898 non-null    float64
#  45  heart_rate_roc_x_std          869 non-null    float64
#  46  heart_rate_roc_y_mean         0 non-null      float64
#  47  heart_rate_roc_y_std          0 non-null      float64
#  48  heart_rate_roc_z_mean         0 non-null      float64
#  49  heart_rate_roc_z_std          0 non-null      float64
#  50  magnetometer_x_mean           980 non-null    float64
#  51  magnetometer_x_std            980 non-null    float64
#  52  magnetometer_y_mean           980 non-null    float64
#  53  magnetometer_y_std            980 non-null    float64
#  54  magnetometer_z_mean           980 non-null    float64
#  55  magnetometer_z_std            980 non-null    float64
#  56  magnetometer_roc_x_mean       980 non-null    float64
#  57  magnetometer_roc_x_std        980 non-null    float64
#  58  magnetometer_roc_y_mean       980 non-null    float64
#  59  magnetometer_roc_y_std        980 non-null    float64
#  60  magnetometer_roc_z_mean       980 non-null    float64
#  61  magnetometer_roc_z_std        980 non-null    float64
#  62  rotation_magnitude_mean       980 non-null    float64
#  63  acceleration_magnitude_mean   980 non-null    float64
#  64  rotation_magnitude_std        980 non-null    float64
#  65  acceleration_magnitude_std    980 non-null    float64
#  66  health_status                 980 non-null    object
#  67  age_group                     980 non-null    object
# dtypes: float64(64), int64(1), object(3)
# memory usage: 520.8+ KB
# None

# %% [markdown]
# ## Dryad (ArWISE) dataset
# https://datadryad.org/landing/show?id=doi%3A10.5061%2Fdryad.jdfn2z3nm#readme

# %%
df1 = pd.read_csv("./combined_filtered_withActivities.csv")
print(df1.info())

# %%
# keywords of columns to keep
eng_cols = ['mean', 'std', 'magnitude', 'label', 'id']

# Filter columns that contain any of the keywords
columns_to_keep = [col for col in df1.columns if any(k in col.lower() for k in eng_cols)]

# Create a new filtered DataFrame
filtered_df1 = df1[columns_to_keep]

# keywords of columns to drop
drop_cols = ['speed','course','home','day']
columns_to_drop = [col for col in filtered_df1.columns if any(k in col.lower() for k in drop_cols)]

filtered_df1 = filtered_df1.drop(columns=columns_to_drop)

print(filtered_df1.info())

# %%
# Detecting missing values
missing_list = list(filtered_df1.columns[filtered_df1.isna().any()])       

# Percentage of missing values
row_count = filtered_df1.shape[0] 
# Create list of dicts (one per column)
data = []
for col in missing_list:
    count = filtered_df1[col].isnull().sum()
    percent = (count / row_count) * 100
    data.append({
        'Columns with missing values': col,
        'Missing count': count,
        'Missing %': percent,
        'DataType' : filtered_df1[col].dtype
    })

# Create DataFrame from list of dicts
missing_df = pd.DataFrame(data)
print(missing_df)

# %%
# looks like 0.04% of dryad dataset have missing values, just drop because we have a lot of data
filtered_df1 = filtered_df1.dropna()

# %%
# Detecting missing values
missing_list = list(filtered_df1.columns[filtered_df1.isna().any()])       

print(missing_list)

# %%
print(mask.info())

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Filter only rows with 'HOA/SCD/MCI'
mask = filtered_df1['group_label'] == 'HOA/SCD/MCI'
hoa_data = filtered_df1.loc[mask]

# Pick numeric health-related features (example columns, change to your real ones)
exclude = ['activity_label', 'group_label', 'user_id']
features = hoa_data.drop(columns=exclude).select_dtypes(include='number').columns
X = hoa_data[features].dropna()

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Cluster into 2 groups: healthy vs unhealthy
# Cluster into 3 groups: HOA, SCD and MCI
kmeans = KMeans(n_clusters=3, random_state=42)
hoa_data['health_cluster'] = kmeans.fit_predict(X_scaled)

# Map cluster IDs to 'healthy'/'unhealthy' after inspecting means
cluster_means = hoa_data.groupby('health_cluster')[features].mean()
print(cluster_means)

# Example mapping after inspection
# cluster_map = {0: 'healthy', 1: 'unhealthy'}  # Adjust based on means
# hoa_data['health_status'] = hoa_data['health_cluster'].map(cluster_map)


# Merge back into original details dataframe
# filtered_df1.loc[mask, 'health_status'] = hoa_data['health_status']

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np

# Reduce to 2D for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Get cluster centers in original space, then transform to PCA space
cluster_centers = hoa_data.groupby('health_cluster')[features].mean().values
cluster_centers_pca = pca.transform(cluster_centers)

# Plot sampled points
sample_idx = np.random.choice(len(X_pca), size=500, replace=False)
plt.scatter(X_pca[sample_idx, 0], X_pca[sample_idx, 1],
            c=hoa_data['health_cluster'].iloc[sample_idx],
            cmap='coolwarm', alpha=0.6)

# Plot cluster means
plt.scatter(cluster_centers_pca[:, 0], cluster_centers_pca[:, 1],
            c='black', marker='X', s=200, label='Cluster Means')

plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("KMeans Clusters with Means")
plt.legend()
plt.show()

# %%
# Get distances to each cluster center
distances = kmeans.transform(X_scaled)

# Calculate "margin" between distances
margin = np.abs(distances[:, 0] - distances[:, 1])

# Keep only points with a large margin (far from boundary)
threshold = np.percentile(margin, 20)  # remove lowest 20% (closest to boundary)
hoa_data_clean = hoa_data[margin > threshold]

print(f"Removed {len(hoa_data) - len(hoa_data_clean)} boundary points")

# %%
from sklearn.decomposition import PCA

# Features from the clean dataset
X_clean = hoa_data_clean[features].dropna()

# Scale using the SAME scaler from before
X_clean_scaled = scaler.transform(X_clean)

# PCA using the SAME pca from before (so axes match original plot)
X_clean_pca = pca.transform(X_clean_scaled)

# Plot clean clusters
# Plot sampled points
sample_idx = np.random.choice(len(X_pca), size=500, replace=False)
plt.scatter(X_pca[sample_idx, 0], X_pca[sample_idx, 1],
            c=hoa_data['health_cluster'].iloc[sample_idx],
            cmap='coolwarm', alpha=0.6)

# Plot cluster centers (same as before)
plt.scatter(cluster_centers_pca[:, 0], cluster_centers_pca[:, 1],
            c='black', marker='X', s=200, label='Cluster Means')

plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("KMeans Clusters (Boundary Points Removed)")
plt.legend(loc='upper right')
plt.show()

# %%
print(hoa_data['health_status'].unique())

# %% [markdown]
# ## Merging datasets

# %%
import pandas as pd

# Assuming filtered_df1 (dryad) and filtered_df3 (ADLfalls) have the same column names
# sort=False keeps order
# if either df doesn't have same columns, leave as NaN
merged_df = pd.concat([filtered_df1, filtered_df3], axis=0, ignore_index=True, sort=False)

# %%
print(merged_df.info())

# %% [markdown]
# ### Drop some features

# %%
# Drop acceleration and magnetometer as these are not in dryad dataset
# Drop yaw pitch roll as these are not in ADLfalls

# keywords of columns to drop
drop_kw = ['yaw','pitch','roll','magnetometer']
columns_to_drop = [col for col in merged_df.columns if any(k in col.lower() for k in drop_kw)]

drop_cols = ['acceleration_x_mean','acceleration_x_std',
             'acceleration_y_mean','acceleration_y_std',
             'acceleration_z_mean','acceleration_z_std'
            ] + columns_to_drop

merged_df = merged_df.drop(columns=drop_cols)

print(merged_df.info())

# %%
# Detecting missing values
missing_list = list(merged_df.columns[merged_df.isna().any()])       

# Percentage of missing values
row_count = merged_df.shape[0] 
# Create list of dicts (one per column)
data = []
for col in missing_list:
    count = merged_df[col].isnull().sum()
    percent = (count / row_count) * 100
    data.append({
        'Columns with missing values': col,
        'Missing count': count,
        'Missing %': percent,
        'DataType' : merged_df[col].dtype
    })

# Create DataFrame from list of dicts
missing_df = pd.DataFrame(data)
print(missing_df)

# %% [markdown]
# ### Standardize and keep only certain activity categories in merged dataset

# %%
# Target categories
# ['Other exercise' 'Hygiene' 'Work' 'Eat' 'Relax' 'Travel' 'Errands' 'Sleep' 'Socialize' 'Walk' 'Hobby' 'Sitting down' 'Climbing stairs' 'Housework' 'Dressing' 'Run' 'Fall']

# Convert to lowercase for easier matching
merged_df['activity_label'] = merged_df['activity_label'].astype(str).str.lower()

# Define mapping function
def categorize_activity(label):
    if 'eat' in label or 'meal' in label or 'drink' in label:
        return 'Eat'
    elif 'errand' in label or 'shop' in label or 'store' in label or 'grocer' in label:
        return 'Errands'
    elif 'exercise' in label or  'workout' in label or 'cycle' in label or  'jump' in label:
        return 'Other exercise'
    elif 'run' in label or 'jog' in label:
        return 'Run'
    elif 'walk' in label:
        return 'Walk'
    elif 'climb' in label:
        return 'Climbing stairs'
    elif 'sit' in label:
        return 'Sitting down'
    elif 'game' in label or 'gaming' in label or 'play' in label or 'art' in label or 'tv' in label or 'read' in label or 'video' in label:
        return 'Hobby'
    elif 'clean' in label or 'chores' in label or 'housework' in label or 'dishes' in label or 'cook' in label:
        return 'Housework'
    elif 'brush' in label or 'toilet' in label or 'shower' in label or 'hygiene' in label or 'groom' in label or 'bath' in label:
        return 'Hygiene'
    elif 'dress' in label or 'makeup' in label or 'hair' in label:
        return 'Dressing'
    elif 'relax' in label or 'chill' in label or 'rest' in label or 'watch' in label:
        return 'Relax'
    elif 'sleep' in label or 'lying' in label or 'lie' in label: # or 'wake' in label or 'bed' in label or 'woke' in label:
        return 'Sleep'
    elif 'social' in label or 'talk' in label or 'phone' in label or 'message' in label or 'text' in label:
        return 'Socialize'
    elif 'travel' in label or 'bus' in label or 'drive' in label or 'commute' in label: # or 'fly' in label
        return 'Travel'
    elif 'work' in label or 'school' in label or 'lab' in label or 'homework' in label or 'report' in label or 'meeting' in label or 'class' in label or 'research' in label or 'study' in label:
        return 'Work'
    elif 'fall' in label:
        return 'Fall'
    else:
        return None # rows not in the above categories will be dropped

# Apply the categorization
merged_df['activity_category'] = merged_df['activity_label'].apply(categorize_activity)

# Drop rows where category is None (would have been 'Other')
merged_df = merged_df[merged_df['activity_category'].notna()]

# %%
print(merged_df['activity_category'].unique())
print(merged_df['group_label'].unique())

# %%
print(merged_df.info())

# %%
# Save final combined dataset

merged_df.to_csv("final_combined.csv", index=False)

# %% [markdown]
# ## Load final combined df

# %%
df = pd.read_csv("./final_combined.csv")
print(df.info())

# %%
# Statistics
# mean, standard deviation, minimum (min), maximum (max), and quartile values
print(df.describe().T)

# %%
# Detecting missing values
missing_list = list(df.columns[df.isna().any()])       

# Percentage of missing values
row_count = df.shape[0] 
# Create list of dicts (one per column)
data = []
for col in missing_list:
    count = df[col].isnull().sum()
    percent = (count / row_count) * 100
    data.append({
        'Columns with missing values': col,
        'Missing count': count,
        'Missing %': percent,
        'DataType' : df[col].dtype
    })

# Create DataFrame from list of dicts
missing_df = pd.DataFrame(data)
print(missing_df)

# %%
print(df['group_label'].unique())

# %% [markdown]
# consider using ADLfalls to learn to cluster HOA vs MCI/? as healthy vs unhealthy
